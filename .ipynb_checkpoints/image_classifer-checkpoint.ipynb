# %% [markdown]
# # Setting up Tensorflow GPU

# %%
import tensorflow as tf
import os

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# # Removing Dodgy Images

# %%
import cv2

# %%
data_dir = 'data'
# data_dir = 'drive/MyDrive/happy_sad_image_classifier/data'
img_exts = ['.jpeg', '.jpg', '.bmp', '.png']
type(img_exts)
# Out:
# list

# %%
for image_class in os.listdir(data_dir):
    if not image_class.startswith('.'):
        for image in os.listdir(os.path.join(data_dir, image_class)):
            image_path = os.path.join(data_dir, image_class, image)
            try:
                img = cv2.imread(image_path)
                _, ext = os.path.splitext(image_path)
                if ext not in list(img_exts):
                    print(f'removing image not in extensions at {image_path}')
                    os.remove(image_path)
            except Exception as e:
                print(f'issue with image: {image_path}')
# Out:
# libpng warning: iCCP: known incorrect sRGB profile

# %% [markdown]
# # Load the data

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
tf.keras.utils.image_dataset_from_directory??
# Out:
# Signature:
# tf.keras.utils.image_dataset_from_directory(
#     directory,
#     labels='inferred',
#     label_mode='int',
#     class_names=None,
#     color_mode='rgb',
#     batch_size=32,
#     image_size=(256, 256),
#     shuffle=True,
#     seed=None,
#     validation_split=None,
#     subset=None,
#     interpolation='bilinear',
#     follow_links=False,
#     crop_to_aspect_ratio=False,
#     pad_to_aspect_ratio=False,
#     data_format=None,
#     verbose=True,
# )
# Source:
# @keras_export(
#     [
#         "keras.utils.image_dataset_from_directory",
#         "keras.preprocessing.image_dataset_from_directory",
#     ]
# )
# def image_dataset_from_directory(
#     directory,
#     labels="inferred",
#     label_mode="int",
#     class_names=None,
#     color_mode="rgb",
#     batch_size=32,
#     image_size=(256, 256),
#     shuffle=True,
#     seed=None,
#     validation_split=None,
#     subset=None,
#     interpolation="bilinear",
#     follow_links=False,
# ...

# %%
data = tf.keras.utils.image_dataset_from_directory('data', label_mode="binary", seed=5, image_size=(512, 512))
# Out:
# Found 1988 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20, 20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# ### happy =  0
# ### sad = 1

# %% [markdown]
# # Preprocess Data

# %%
data = data.map(lambda x,y: (x/255, y))

# %% [markdown]
# # Split Data

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2) + 1
test_size = int(len(data)*.1)

# %%
train_data = data.take(train_size)
val_data = data.skip(train_size).take(val_size)
test_data = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# # Deep Learning Model

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

# %%
# Load the ResNet50 model with pre-trained weights, excluding the top layer
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(512, 512, 3))

# Freeze the base model
base_model.trainable = False

x = base_model.output
x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.25)(x)

x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.25)(x)

x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
outputs = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=outputs)

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_160"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_17      │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 518, 518,  │          0 │ input_layer_17[0… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 256, 256,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %% [markdown]
# # Train

# %%
logs_dir = 'logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logs_dir)

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping_monitor = EarlyStopping(
    monitor='val_loss',
    patience=5,
    verbose=2,
    restore_best_weights=True,
    start_from_epoch=30
)

# %%
history = model.fit(train_data, epochs=50, validation_data=val_data, callbacks=[tensorboard_callback] )
# Out:
# Epoch 1/10
# 2024-06-22 19:07:28.953474: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5038 - loss: 1.4506
# 2024-06-22 19:09:28.108445: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 157s 3s/step - accuracy: 0.5038 - loss: 1.4431 - val_accuracy: 0.5409 - val_loss: 0.6906
# Epoch 2/10
#  8/44 ━━━━━━━━━━━━━━━━━━━━ 1:26 2s/step - accuracy: 0.4846 - loss: 0.7343
# 2024-06-22 19:10:20.327357: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5120 - loss: 0.7302
# 2024-06-22 19:11:56.399667: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 153s 3s/step - accuracy: 0.5125 - loss: 0.7300 - val_accuracy: 0.5264 - val_loss: 0.6936
# Epoch 3/10
# ...

# %% [markdown]
# # Plot Evaluation Metrics

# %%
fig = plt.figure()
plt.plot(history.history['loss'], color='brown', label='loss')
plt.plot(history.history['val_loss'], color='blue', label='validation Loss')
fig.suptitle('Loss Graph', fontsize=20)
plt.legend(loc="upper right")
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['accuracy'], color='brown', label='accuracy')
plt.plot(history.history['val_accuracy'], color='blue', label='val_accuracy')
fig.suptitle('Accuracy Graph', fontsize=20)
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# # Evaluate

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
precision = Precision()
recall = Recall()
accuracy = BinaryAccuracy()

# %%
for batch in test_data.as_numpy_iterator():
    X, y = batch
    Yhat = model.predict(X)
    precision.update_state(y, Yhat)
    recall.update_state(y, Yhat)
    accuracy.update_state(y, Yhat)
# Out:
# 2024-06-22 19:51:07.724922: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 2024-06-22 19:51:33.677071: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
print(f'Precision: {precision.result().numpy()}, Accuracy: {accuracy.result().numpy()}, Recall: {recall.result().numpy()}')
# Out:
# Precision: 0.44720497727394104, Accuracy: 0.45121949911117554, Recall: 0.9863013625144958

# %% [markdown]
# # Save Model

# %%
model.save(os.path.join('models', 'image_classifier.keras'))
